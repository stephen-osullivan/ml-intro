# %% [markdown]
# ### This notebook walks through fitting models to the IRIS dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris(as_frame=True)
print(iris.keys())
data = iris['data']
data['label'] = pd.Categorical(iris['target'])
data
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# ...

# %%
data['is_train'] = np.random.uniform(size=len(data)) < 0.66
data['is_train'].value_counts()
# Out:
# is_train
# True     112
# False     38
# Name: count, dtype: int64

# %%
g = sns.pairplot(data, hue='label', height=2, plot_kws={"alpha":0.5})
plt.show()
